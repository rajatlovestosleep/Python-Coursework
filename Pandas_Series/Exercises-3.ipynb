# %% [markdown]
# ### Extracting Series Values by Index Labels

# %% [markdown]
# ### Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Load another csv file from this <a href= "https://raw.githubusercontent.com/Prajwalk09/Data-Analysis-with-Pandas-and-Python/refs/heads/main/Series/pokemon.csv">link</a> into a varaible called `pokemon_data`. Set the *Pokemon* column as the *Index* column and store the result as a Series

# %%
pokemon_data = pd.read_csv('https://raw.githubusercontent.com/Prajwalk09/Data-Analysis-with-Pandas-and-Python/refs/heads/main/Series/pokemon.csv', index_col="Pokemon")["Type"]
pokemon_data
# Out:
# Pokemon
# Bulbasaur       Grass
# Ivysaur         Grass
# Venusaur        Grass
# Charmander       Fire
# Charmeleon       Fire
#                ...
# Yveltal          Dark
# Zygarde        Dragon
# Diancie          Rock
# Hoopa         Psychic
# Volcanion        Fire
# Name: Type, Length: 721, dtype: object

# %%
type(pokemon_data)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Retrieve and display the values associated with the index `'Charizard'` and `'Pikachu'` from the `pokemon` Series

# %%
pokemon_data['Charizard']
# Out:
# 'Fire'

# %% [markdown]
# ### Retrieve and display the values at the `'second'` and `'third'` indices, respectively

# %%
pokemon_data.iloc[1:2]
# Out:
# Pokemon
# Ivysaur    Grass
# Name: Type, dtype: object

# %%
pokemon_data.iloc[2:3]
# Out:
# Pokemon
# Venusaur    Grass
# Name: Type, dtype: object

# %% [markdown]
# ### Retrieve and display the data from the `pokemon` Series for the range of indices from `'Charmander'` to `'Weedle'`

# %%
pokemon_data.loc['Charmander':'Weedle']
# Out:
# Pokemon
# Charmander     Fire
# Charmeleon     Fire
# Charizard      Fire
# Squirtle      Water
# Wartortle     Water
# Blastoise     Water
# Caterpie        Bug
# Metapod         Bug
# Butterfree      Bug
# Weedle          Bug
# Name: Type, dtype: object

# %% [markdown]
# ### Sort the `pokemon` Series by its index in ascending order

# %%
pokemon_data.sort_index
# Out:
# <bound method Series.sort_index of Pokemon
# Bulbasaur       Grass
# Ivysaur         Grass
# Venusaur        Grass
# Charmander       Fire
# Charmeleon       Fire
#                ...
# Yveltal          Dark
# Zygarde        Dragon
# Diancie          Rock
# Hoopa         Psychic
# Volcanion        Fire
# Name: Type, Length: 721, dtype: object>

# %% [markdown]
# ### Count and display the occurrences of each unique value in the `pokemon` Series

# %%
pokemon_data.value_counts()
# Out:
# Type
# Water       105
# Normal       93
# Grass        66
# Bug          63
# Fire         47
# Psychic      47
# Rock         41
# Electric     36
# Ground       30
# Poison       28
# Dark         28
# Fighting     25
# Dragon       24
# Ice          23
# Ghost        23
# Steel        22
# Fairy        17
# Flying        3
# Name: count, dtype: int64

# %% [markdown]
# ### Load another csv file from this <a href= "https://raw.githubusercontent.com/Prajwalk09/Data-Analysis-with-Pandas-and-Python/refs/heads/main/Series/google_stock_price.csv">link</a> into a varaible called `stock_data`. Display the first few rows of this Series

# %%
stock_data = pd.read_csv('https://raw.githubusercontent.com/Prajwalk09/Data-Analysis-with-Pandas-and-Python/refs/heads/main/Series/google_stock_price.csv')["Stock Price"]

# %%
stock_data.head()
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# Name: Stock Price, dtype: float64

# %% [markdown]
# ### Write a function named `classify_performance` that takes a stock price as input and returns:
# - `"Okay"` if the stock price is less than 300.
# - `"Satisfactory"` if the stock price is between 300 and 650 (inclusive).
# - `"Incredible!"` if the stock price is greater than 650.

# %%
def classify_performance(stock_price):
    if stock_price < 300:
        return "Okay"
    elif 300 <= stock_price <= 650:
        return "Satisfactory"
    else:
        return "Incredible!"

# %% [markdown]
# ### Apply the `classify_performance` function to the `stock_data` Series and count the occurrences of each performance category

# %%
performance_counts = stock_data.apply(classify_performance).value_counts()
print(performance_counts)
# Out:
# Stock Price
# Okay            1721
# Satisfactory    1075
# Incredible!      216
# Name: count, dtype: int64

# %% [markdown]
# ### Assignment : Try implementing the same operation using a `lambda` function

# %%
performance = stock_data.apply(
    lambda x: "Okay" if x < 300 
              else "Satisfactory" if x <= 650 
              else "Incredible!"
)

counts = performance.value_counts()
print(counts)
# Out:
# Stock Price
# Okay            1721
# Satisfactory    1075
# Incredible!      216
# Name: count, dtype: int64
