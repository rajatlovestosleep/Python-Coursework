# %% [markdown]
# ### Reading Files in Pandas

# %% [markdown]
# ### Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Load the csv file from this <a href = "https://raw.githubusercontent.com/Prajwalk09/Data-Analysis-with-Pandas-and-Python/refs/heads/main/Series/google_stock_price.csv">link</a> into a variable called `stock_data` as a Series

# %%
stock_data=pd.read_csv("https://raw.githubusercontent.com/Prajwalk09/Data-Analysis-with-Pandas-and-Python/refs/heads/main/Series/google_stock_price.csv")
s=pd.Series(stock_data["Stock Price"])
s
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
#          ...
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, Length: 3012, dtype: float64

# %% [markdown]
# ### Load another csv file from this <a href= "https://raw.githubusercontent.com/Prajwalk09/Data-Analysis-with-Pandas-and-Python/refs/heads/main/Series/pokemon.csv">link</a> into a varaible called `pokemon_data`. Use only the *Pokemon* column and store the result as a Series

# %%
pokemon_data=pd.read_csv('https://raw.githubusercontent.com/Prajwalk09/Data-Analysis-with-Pandas-and-Python/refs/heads/main/Series/pokemon.csv')
p=pd.Series(pokemon_data["Pokemon"])
p
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %% [markdown]
# ### Display the first 5 rows from both the variables

# %%
s.head()
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# Name: Stock Price, dtype: float64

# %%
p.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %% [markdown]
# ### Display the length of the `pokemon_data` variable

# %%
len(pokemon_data)
# Out:
# 721

# %% [markdown]
# ### Use the `min()` and `max()` functions on `stock_data` and `pokemon_data`

# %% [markdown]
# <span style="font-size:14px; color:blue;">What conclusions can you make about the behavior of `min()` and `max()` when applied to non-numeric data?</span>

# %%
min(pokemon_data)
# Out:
# 'Pokemon'

# %%
max(pokemon_data)
# Out:
# 'Type'

# %%
min(stock_data)
# Out:
# 'Stock Price'

# %%
max(stock_data)
# Out:
# 'Stock Price'

# %% [markdown]
# ### Sort the values in the `pokemon_data` in ascending order and the values in `stock_data` in descending order

# %%
p.sort_values()
# Out:
# 459    Abomasnow
# 62          Abra
# 358        Absol
# 616     Accelgor
# 680    Aegislash
#          ...
# 570      Zoroark
# 569        Zorua
# 40         Zubat
# 633     Zweilous
# 717      Zygarde
# Name: Pokemon, Length: 721, dtype: object

# %%
s.sort_values(ascending = False)
# Out:
# 3011    782.22
# 2859    776.60
# 3009    773.18
# 3007    772.88
# 3010    771.61
#          ...
# 12       50.74
# 10       50.70
# 0        50.12
# 9        50.07
# 11       49.95
# Name: Stock Price, Length: 3012, dtype: float64

# %% [markdown]
# ### Extract the 5th value from the `pokemon_data` Series

# %%
#Using Indexing
print(p[5:6])

#Using at method
p.at[5]
# Out:
# 5    Charizard
# Name: Pokemon, dtype: object
# 'Charizard'

# %% [markdown]
# ### Extract the 10th, 15th and 20th value from the `pokemon_data` Series

# %%
#Using Indexing
print(p[10:11])

#Using at method
p.at[10]
# Out:
# 10    Metapod
# Name: Pokemon, dtype: object
# 'Metapod'

# %%
#Using Indexing
print(p[15:16])

#Using at method
p.at[15]
# Out:
# 15    Pidgey
# Name: Pokemon, dtype: object
# 'Pidgey'

# %%
#Using Indexing
print(p[20:21])

#Using at method
p.at[20]
# Out:
# 20    Spearow
# Name: Pokemon, dtype: object
# 'Spearow'

# %% [markdown]
# ### Extract all the values between the 10th and 20th index in the `pokemon_data` Series

# %%
#Using Indexing
print(p[10:21])
# Out:
# 10       Metapod
# 11    Butterfree
# 12        Weedle
# 13        Kakuna
# 14      Beedrill
# 15        Pidgey
# 16     Pidgeotto
# 17       Pidgeot
# 18       Rattata
# 19      Raticate
# 20       Spearow
# Name: Pokemon, dtype: object

# %%
#Using loc and iloc
p.iloc[10:21]
# Out:
# 10       Metapod
# 11    Butterfree
# 12        Weedle
# 13        Kakuna
# 14      Beedrill
# 15        Pidgey
# 16     Pidgeotto
# 17       Pidgeot
# 18       Rattata
# 19      Raticate
# 20       Spearow
# Name: Pokemon, dtype: object
